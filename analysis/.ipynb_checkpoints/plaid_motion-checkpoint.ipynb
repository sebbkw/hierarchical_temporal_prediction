# %%
import sys
from itertools import combinations
import numpy as np
import scipy.stats as stats
import torch
import pingouin as pg
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Arial"

from plaid_data import plaid_data
PI_dist_V1 = plaid_data['PI_dist_V1']
PI_dist_V2 = plaid_data['PI_dist_V2']
PI_dist_MT = plaid_data['PI_dist_MT']

# Import custom modules
sys.path.append("../")
from models.network_hierarchical_recurrent import NetworkHierarchicalRecurrent
from models.network_feedforward_stacked import NetworkFeedforwardStacked
from virtual_physiology_20x40.VirtualNetworkPhysiology import VirtualPhysiology
from plotting_functions import *

COLORS = ['tab:blue', 'tab:red', 'tab:green', 'tab:gray']

def not_nan (arr):
    return [a for a in arr if not np.isnan(a)]
# Out:
# /home/seb/anaconda3/envs/allensdk/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/seb/anaconda3/envs/allensdk/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.3, the latest is 0.5.5.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
MODEL_PATH = ''
VPHYS_PATH = ''
UNITS      = 800

# Load model
model, hyperparameters, loss_history = NetworkHierarchicalRecurrent.load(
    model_path=MODEL_PATH,
    device='cpu',
    plot_loss_history=False
)

# Load previously processed vphys data
vphys = VirtualPhysiology.load(
    data_path=VPHYS_PATH,
    model=model,
    hyperparameters=hyperparameters,
    hidden_units=[UNITS, UNITS, UNITS],
    frame_shape=(20, 40),
    device='cpu'
)

physiology_data_group1 = vphys.data[0]
physiology_data_group2 = vphys.data[1]
physiology_data_group3 = vphys.data[2]

# Global vars
FRAME_SIZE           = hyperparameters["frame_size"]
WARMUP               = hyperparameters["warmup"]
T_STEPS              = 40
TEMPORAL_FREQUENCIES = vphys.temporal_frequencies
SPATIAL_FREQUENCIES  = vphys.spatial_frequencies
ORIENTATIONS         = vphys.orientations
FRAME_SHAPE          = (20, 40)

COLORS = ['tab:blue', 'tab:red', 'tab:green', 'tab:gray']

HEIGHT, WIDTH = FRAME_SHAPE

# %% [markdown]
# # Mean plaid tuning curve

# %%
def get_DSI (tuning_curve):
    orient_pref_idx = np.argmax(tuning_curve)
    orient_pref = np.max(tuning_curve)
    
    orient_opp_idx = (orient_pref_idx + len(tuning_curve)//2) % len(tuning_curve)
    orient_opp = tuning_curve[orient_opp_idx]

    DSI = (orient_pref - orient_opp) / (orient_pref + orient_opp)

    return DSI
    
plaid_selective_DSI_all = []
    
for group in vphys.data:
    plaid_selective_units = [u for u in group if u['plaid_pattern_index']>0]
    plaid_selective_DSI = [get_DSI(u['plaid_response']) for u in plaid_selective_units]
    plaid_selective_DSI_all += plaid_selective_DSI
    
    DS_pct = round(len([u for u in plaid_selective_DSI if u>0.3])/len(plaid_selective_DSI) * 100, 2)
    
    print(len(plaid_selective_DSI), '\t', DS_pct, '%', '\t', np.mean(plaid_selective_DSI))
    
print(
    round(len([u for u in plaid_selective_DSI_all if u>0.3])/len(plaid_selective_DSI_all) * 100, 2),
    '\t', 
    np.mean(plaid_selective_DSI_all)
)
# Out:
# 25 	 80.0 % 	 0.67745954
# 21 	 66.67 % 	 0.5982228
# 10 	 70.0 % 	 0.6706088
# 73.21 	 0.6465224

# %% [markdown]
# # Distribution with and without feedback

# %%
model_nofb, hyperparameters, _ = NetworkHierarchicalRecurrent.load(
    model_path=MODEL_PATH, device='cpu'
)

pct_inactivated = 1
mask_1 = np.random.choice([0,1], size=(800, 800), p=[pct_inactivated,1-pct_inactivated])
mask_2 = np.random.choice([0,1], size=(800, 800), p=[pct_inactivated,1-pct_inactivated])
weights = model.rnn.weight_hh_l0.detach().cpu().numpy().copy()
weights[0:800, 800:1600] = weights[0:800, 800:1600]*mask_1
weights[800:1600, 1600:2400] = weights[800:1600, 1600:2400]*mask_2
model_nofb.rnn.weight_hh_l0 = torch.nn.Parameter(torch.Tensor(weights).to('cpu'))

# Instantiate new VirtualPhysiology object
vphys_nofb = VirtualPhysiology.load(
    data_path=VPHYS_PATH,
    model=model_nofb,
    hyperparameters=hyperparameters,
    frame_shape=(20, 40),
    hidden_units=[800, 800, 800],
    device='cpu'
)

vphys_nofb.get_plaid_pattern_index()
# Out:
# Multi plaid component angles
# Finished unit 1 / 800, group 1 / 3
# Finished unit 2 / 800, group 1 / 3
# Finished unit 3 / 800, group 1 / 3
# Finished unit 4 / 800, group 1 / 3
# Finished unit 5 / 800, group 1 / 3
# Finished unit 6 / 800, group 1 / 3
# Finished unit 7 / 800, group 1 / 3
# Finished unit 8 / 800, group 1 / 3
# Finished unit 9 / 800, group 1 / 3
# Finished unit 10 / 800, group 1 / 3
# Finished unit 11 / 800, group 1 / 3
# Finished unit 12 / 800, group 1 / 3
# Finished unit 13 / 800, group 1 / 3
# Finished unit 14 / 800, group 1 / 3
# Finished unit 15 / 800, group 1 / 3
# Finished unit 16 / 800, group 1 / 3
# Finished unit 17 / 800, group 1 / 3
# Finished unit 18 / 800, group 1 / 3
# Finished unit 19 / 800, group 1 / 3
# Finished unit 20 / 800, group 1 / 3
# Finished unit 21 / 800, group 1 / 3
# Finished unit 22 / 800, group 1 / 3
# Finished unit 23 / 800, group 1 / 3
# Finished unit 24 / 800, group 1 / 3
# Finished unit 25 / 800, group 1 / 3
# Finished unit 26 / 800, group 1 / 3
# Finished unit 27 / 800, group 1 / 3
# Finished unit 28 / 800, group 1 / 3
# Finished unit 29 / 800, group 1 / 3
# Finished unit 30 / 800, group 1 / 3
# Finished unit 31 / 800, group 1 / 3
# Finished unit 32 / 800, group 1 / 3
# Finished unit 33 / 800, group 1 / 3
# Finished unit 34 / 800, group 1 / 3
# Finished unit 35 / 800, group 1 / 3
# Finished unit 36 / 800, group 1 / 3
# Finished unit 37 / 800, group 1 / 3
# Finished unit 38 / 800, group 1 / 3
# Finished unit 39 / 800, group 1 / 3
# Finished unit 40 / 800, group 1 / 3
# Finished unit 41 / 800, group 1 / 3
# Finished unit 42 / 800, group 1 / 3
# Finished unit 43 / 800, group 1 / 3
# Finished unit 44 / 800, group 1 / 3
# Finished unit 45 / 800, group 1 / 3
# Finished unit 46 / 800, group 1 / 3
# Finished unit 47 / 800, group 1 / 3
# Finished unit 48 / 800, group 1 / 3
# Finished unit 49 / 800, group 1 / 3
# Finished unit 50 / 800, group 1 / 3
# Finished unit 51 / 800, group 1 / 3
# Finished unit 52 / 800, group 1 / 3
# Finished unit 53 / 800, group 1 / 3
# Finished unit 54 / 800, group 1 / 3
# Finished unit 55 / 800, group 1 / 3
# Finished unit 56 / 800, group 1 / 3
# Finished unit 57 / 800, group 1 / 3
# Finished unit 58 / 800, group 1 / 3
# Finished unit 59 / 800, group 1 / 3
# Finished unit 60 / 800, group 1 / 3
# Finished unit 61 / 800, group 1 / 3
# Finished unit 62 / 800, group 1 / 3
# Finished unit 63 / 800, group 1 / 3
# Finished unit 64 / 800, group 1 / 3
# Finished unit 65 / 800, group 1 / 3
# Finished unit 66 / 800, group 1 / 3
# Finished unit 67 / 800, group 1 / 3
# Finished unit 68 / 800, group 1 / 3
# Finished unit 69 / 800, group 1 / 3
# Finished unit 70 / 800, group 1 / 3
# Finished unit 71 / 800, group 1 / 3
# Finished unit 72 / 800, group 1 / 3
# Finished unit 73 / 800, group 1 / 3
# Finished unit 74 / 800, group 1 / 3
# Finished unit 75 / 800, group 1 / 3
# Finished unit 76 / 800, group 1 / 3
# Finished unit 77 / 800, group 1 / 3
# Finished unit 78 / 800, group 1 / 3
# Finished unit 79 / 800, group 1 / 3
# Finished unit 80 / 800, group 1 / 3
# Finished unit 81 / 800, group 1 / 3
# Finished unit 82 / 800, group 1 / 3
# Finished unit 83 / 800, group 1 / 3
# Finished unit 84 / 800, group 1 / 3
# Finished unit 85 / 800, group 1 / 3
# Finished unit 86 / 800, group 1 / 3
# Finished unit 87 / 800, group 1 / 3
# Finished unit 88 / 800, group 1 / 3
# Finished unit 89 / 800, group 1 / 3
# Finished unit 90 / 800, group 1 / 3
# Finished unit 91 / 800, group 1 / 3
# Finished unit 92 / 800, group 1 / 3
# Finished unit 93 / 800, group 1 / 3
# Finished unit 94 / 800, group 1 / 3
# Finished unit 95 / 800, group 1 / 3
# Finished unit 96 / 800, group 1 / 3
# Finished unit 97 / 800, group 1 / 3
# Finished unit 98 / 800, group 1 / 3
# Finished unit 99 / 800, group 1 / 3
# Finished unit 100 / 800, group 1 / 3
# Finished unit 101 / 800, group 1 / 3
# Finished unit 102 / 800, group 1 / 3
# Finished unit 103 / 800, group 1 / 3
# Finished unit 104 / 800, group 1 / 3
# Finished unit 105 / 800, group 1 / 3
# Finished unit 106 / 800, group 1 / 3
# Finished unit 107 / 800, group 1 / 3
# Finished unit 108 / 800, group 1 / 3
# Finished unit 109 / 800, group 1 / 3
# Finished unit 110 / 800, group 1 / 3
# Finished unit 111 / 800, group 1 / 3
# Finished unit 112 / 800, group 1 / 3
# Finished unit 113 / 800, group 1 / 3
# Finished unit 114 / 800, group 1 / 3
# Finished unit 115 / 800, group 1 / 3
# Finished unit 116 / 800, group 1 / 3
# Finished unit 117 / 800, group 1 / 3
# Finished unit 118 / 800, group 1 / 3
# Finished unit 119 / 800, group 1 / 3
# Finished unit 120 / 800, group 1 / 3
# Finished unit 121 / 800, group 1 / 3
# Finished unit 122 / 800, group 1 / 3
# Finished unit 123 / 800, group 1 / 3
# Finished unit 124 / 800, group 1 / 3
# Finished unit 125 / 800, group 1 / 3
# Finished unit 126 / 800, group 1 / 3
# Finished unit 127 / 800, group 1 / 3
# Finished unit 128 / 800, group 1 / 3
# Finished unit 129 / 800, group 1 / 3
# Finished unit 130 / 800, group 1 / 3
# Finished unit 131 / 800, group 1 / 3
# Finished unit 132 / 800, group 1 / 3
# Finished unit 133 / 800, group 1 / 3
# Finished unit 134 / 800, group 1 / 3
# Finished unit 135 / 800, group 1 / 3
# Finished unit 136 / 800, group 1 / 3
# Finished unit 137 / 800, group 1 / 3
# Finished unit 138 / 800, group 1 / 3
# Finished unit 139 / 800, group 1 / 3
# Finished unit 140 / 800, group 1 / 3
# Finished unit 141 / 800, group 1 / 3
# Finished unit 142 / 800, group 1 / 3
# Finished unit 143 / 800, group 1 / 3
# Finished unit 144 / 800, group 1 / 3
# Finished unit 145 / 800, group 1 / 3
# Finished unit 146 / 800, group 1 / 3
# Finished unit 147 / 800, group 1 / 3
# Finished unit 148 / 800, group 1 / 3
# Finished unit 149 / 800, group 1 / 3
# Finished unit 150 / 800, group 1 / 3
# Finished unit 151 / 800, group 1 / 3
# Finished unit 152 / 800, group 1 / 3
# Finished unit 153 / 800, group 1 / 3
# Finished unit 154 / 800, group 1 / 3
# Finished unit 155 / 800, group 1 / 3
# Finished unit 156 / 800, group 1 / 3
# Finished unit 157 / 800, group 1 / 3
# Finished unit 158 / 800, group 1 / 3
# Finished unit 159 / 800, group 1 / 3
# Finished unit 160 / 800, group 1 / 3
# Finished unit 161 / 800, group 1 / 3
# Finished unit 162 / 800, group 1 / 3
# Finished unit 163 / 800, group 1 / 3
# Finished unit 164 / 800, group 1 / 3
# Finished unit 165 / 800, group 1 / 3
# Finished unit 166 / 800, group 1 / 3
# Finished unit 167 / 800, group 1 / 3
# Finished unit 168 / 800, group 1 / 3
# Finished unit 169 / 800, group 1 / 3
# Finished unit 170 / 800, group 1 / 3
# Finished unit 171 / 800, group 1 / 3
# Finished unit 172 / 800, group 1 / 3
# Finished unit 173 / 800, group 1 / 3
# Finished unit 174 / 800, group 1 / 3
# Finished unit 175 / 800, group 1 / 3
# Finished unit 176 / 800, group 1 / 3
# Finished unit 177 / 800, group 1 / 3
# Finished unit 178 / 800, group 1 / 3
# Finished unit 179 / 800, group 1 / 3
# Finished unit 180 / 800, group 1 / 3
# Finished unit 181 / 800, group 1 / 3
# Finished unit 182 / 800, group 1 / 3
# Finished unit 183 / 800, group 1 / 3
# Finished unit 184 / 800, group 1 / 3
# Finished unit 185 / 800, group 1 / 3
# Finished unit 186 / 800, group 1 / 3
# Finished unit 187 / 800, group 1 / 3
# Finished unit 188 / 800, group 1 / 3
# Finished unit 189 / 800, group 1 / 3
# Finished unit 190 / 800, group 1 / 3
# Finished unit 191 / 800, group 1 / 3
# Finished unit 192 / 800, group 1 / 3
# Finished unit 193 / 800, group 1 / 3
# Finished unit 194 / 800, group 1 / 3
# Finished unit 195 / 800, group 1 / 3
# Finished unit 196 / 800, group 1 / 3
# Finished unit 197 / 800, group 1 / 3
# Finished unit 198 / 800, group 1 / 3
# Finished unit 199 / 800, group 1 / 3
# Finished unit 200 / 800, group 1 / 3
# Finished unit 201 / 800, group 1 / 3
# Finished unit 202 / 800, group 1 / 3
# Finished unit 203 / 800, group 1 / 3
# Finished unit 204 / 800, group 1 / 3
# Finished unit 205 / 800, group 1 / 3
# Finished unit 206 / 800, group 1 / 3
# Finished unit 207 / 800, group 1 / 3
# Finished unit 208 / 800, group 1 / 3
# Finished unit 209 / 800, group 1 / 3
# Finished unit 210 / 800, group 1 / 3
# Finished unit 211 / 800, group 1 / 3
# Finished unit 212 / 800, group 1 / 3
# Finished unit 213 / 800, group 1 / 3
# Finished unit 214 / 800, group 1 / 3
# Finished unit 215 / 800, group 1 / 3
# Finished unit 216 / 800, group 1 / 3
# Finished unit 217 / 800, group 1 / 3
# Finished unit 218 / 800, group 1 / 3
# Finished unit 219 / 800, group 1 / 3
# Finished unit 220 / 800, group 1 / 3
# Finished unit 221 / 800, group 1 / 3
# Finished unit 222 / 800, group 1 / 3
# Finished unit 223 / 800, group 1 / 3
# Finished unit 224 / 800, group 1 / 3
# Finished unit 225 / 800, group 1 / 3
# Finished unit 226 / 800, group 1 / 3
# Finished unit 227 / 800, group 1 / 3
# Finished unit 228 / 800, group 1 / 3
# Finished unit 229 / 800, group 1 / 3
# Finished unit 230 / 800, group 1 / 3
# Finished unit 231 / 800, group 1 / 3
# Finished unit 232 / 800, group 1 / 3
# Finished unit 233 / 800, group 1 / 3
# Finished unit 234 / 800, group 1 / 3
# Finished unit 235 / 800, group 1 / 3
# Finished unit 236 / 800, group 1 / 3
# Finished unit 237 / 800, group 1 / 3
# Finished unit 238 / 800, group 1 / 3
# Finished unit 239 / 800, group 1 / 3
# Finished unit 240 / 800, group 1 / 3
# Finished unit 241 / 800, group 1 / 3
# Finished unit 242 / 800, group 1 / 3
# Finished unit 243 / 800, group 1 / 3
# Finished unit 244 / 800, group 1 / 3
# Finished unit 245 / 800, group 1 / 3
# Finished unit 246 / 800, group 1 / 3
# Finished unit 247 / 800, group 1 / 3
# Finished unit 248 / 800, group 1 / 3
# Finished unit 249 / 800, group 1 / 3
# Finished unit 250 / 800, group 1 / 3
# Finished unit 251 / 800, group 1 / 3
# Finished unit 252 / 800, group 1 / 3
# Finished unit 253 / 800, group 1 / 3
# Finished unit 254 / 800, group 1 / 3
# Finished unit 255 / 800, group 1 / 3
# Finished unit 256 / 800, group 1 / 3
# Finished unit 257 / 800, group 1 / 3
# Finished unit 258 / 800, group 1 / 3
# Finished unit 259 / 800, group 1 / 3
# Finished unit 260 / 800, group 1 / 3
# Finished unit 261 / 800, group 1 / 3
# Finished unit 262 / 800, group 1 / 3
# Finished unit 263 / 800, group 1 / 3
# Finished unit 264 / 800, group 1 / 3
# Finished unit 265 / 800, group 1 / 3
# Finished unit 266 / 800, group 1 / 3
# Finished unit 267 / 800, group 1 / 3
# Finished unit 268 / 800, group 1 / 3
# Finished unit 269 / 800, group 1 / 3
# Finished unit 270 / 800, group 1 / 3
# Finished unit 271 / 800, group 1 / 3
# Finished unit 272 / 800, group 1 / 3
# Finished unit 273 / 800, group 1 / 3
# Finished unit 274 / 800, group 1 / 3
# Finished unit 275 / 800, group 1 / 3
# Finished unit 276 / 800, group 1 / 3
# Finished unit 277 / 800, group 1 / 3
# Finished unit 278 / 800, group 1 / 3
# Finished unit 279 / 800, group 1 / 3
# Finished unit 280 / 800, group 1 / 3
# Finished unit 281 / 800, group 1 / 3
# Finished unit 282 / 800, group 1 / 3
# Finished unit 283 / 800, group 1 / 3
# Finished unit 284 / 800, group 1 / 3
# Finished unit 285 / 800, group 1 / 3
# Finished unit 286 / 800, group 1 / 3
# Finished unit 287 / 800, group 1 / 3
# Finished unit 288 / 800, group 1 / 3
# Finished unit 289 / 800, group 1 / 3
# Finished unit 290 / 800, group 1 / 3
# Finished unit 291 / 800, group 1 / 3
# Finished unit 292 / 800, group 1 / 3
# Finished unit 293 / 800, group 1 / 3
# Finished unit 294 / 800, group 1 / 3
# Finished unit 295 / 800, group 1 / 3
# Finished unit 296 / 800, group 1 / 3
# Finished unit 297 / 800, group 1 / 3
# Finished unit 298 / 800, group 1 / 3
# Finished unit 299 / 800, group 1 / 3
# Finished unit 300 / 800, group 1 / 3
# Finished unit 301 / 800, group 1 / 3
# Finished unit 302 / 800, group 1 / 3
# Finished unit 303 / 800, group 1 / 3
# Finished unit 304 / 800, group 1 / 3
# Finished unit 305 / 800, group 1 / 3
# Finished unit 306 / 800, group 1 / 3
# Finished unit 307 / 800, group 1 / 3
# Finished unit 308 / 800, group 1 / 3
# Finished unit 309 / 800, group 1 / 3
# Finished unit 310 / 800, group 1 / 3
# Finished unit 311 / 800, group 1 / 3
# Finished unit 312 / 800, group 1 / 3
# Finished unit 313 / 800, group 1 / 3
# Finished unit 314 / 800, group 1 / 3
# Finished unit 315 / 800, group 1 / 3
# Finished unit 316 / 800, group 1 / 3
# Finished unit 317 / 800, group 1 / 3
# Finished unit 318 / 800, group 1 / 3
# Finished unit 319 / 800, group 1 / 3
# Finished unit 320 / 800, group 1 / 3
# Finished unit 321 / 800, group 1 / 3
# Finished unit 322 / 800, group 1 / 3
# Finished unit 323 / 800, group 1 / 3
# Finished unit 324 / 800, group 1 / 3
# Finished unit 325 / 800, group 1 / 3
# Finished unit 326 / 800, group 1 / 3
# Finished unit 327 / 800, group 1 / 3
# Finished unit 328 / 800, group 1 / 3
# Finished unit 329 / 800, group 1 / 3
# Finished unit 330 / 800, group 1 / 3
# Finished unit 331 / 800, group 1 / 3
# Finished unit 332 / 800, group 1 / 3
# Finished unit 333 / 800, group 1 / 3
# Finished unit 334 / 800, group 1 / 3
# Finished unit 335 / 800, group 1 / 3
# Finished unit 336 / 800, group 1 / 3
# Finished unit 337 / 800, group 1 / 3
# Finished unit 338 / 800, group 1 / 3
# Finished unit 339 / 800, group 1 / 3
# Finished unit 340 / 800, group 1 / 3
# Finished unit 341 / 800, group 1 / 3
# Finished unit 342 / 800, group 1 / 3
# Finished unit 343 / 800, group 1 / 3
# Finished unit 344 / 800, group 1 / 3
# Finished unit 345 / 800, group 1 / 3
# Finished unit 346 / 800, group 1 / 3
# Finished unit 347 / 800, group 1 / 3
# Finished unit 348 / 800, group 1 / 3
# Finished unit 349 / 800, group 1 / 3
# Finished unit 350 / 800, group 1 / 3
# Finished unit 351 / 800, group 1 / 3
# Finished unit 352 / 800, group 1 / 3
# Finished unit 353 / 800, group 1 / 3
# Finished unit 354 / 800, group 1 / 3
# Finished unit 355 / 800, group 1 / 3
# Finished unit 356 / 800, group 1 / 3
# Finished unit 357 / 800, group 1 / 3
# Finished unit 358 / 800, group 1 / 3
# Finished unit 359 / 800, group 1 / 3
# Finished unit 360 / 800, group 1 / 3
# Finished unit 361 / 800, group 1 / 3
# Finished unit 362 / 800, group 1 / 3
# Finished unit 363 / 800, group 1 / 3
# Finished unit 364 / 800, group 1 / 3
# Finished unit 365 / 800, group 1 / 3
# Finished unit 366 / 800, group 1 / 3
# Finished unit 367 / 800, group 1 / 3
# Finished unit 368 / 800, group 1 / 3
# Finished unit 369 / 800, group 1 / 3
# Finished unit 370 / 800, group 1 / 3
# Finished unit 371 / 800, group 1 / 3
# Finished unit 372 / 800, group 1 / 3
# Finished unit 373 / 800, group 1 / 3
# Finished unit 374 / 800, group 1 / 3
# Finished unit 375 / 800, group 1 / 3
# Finished unit 376 / 800, group 1 / 3
# Finished unit 377 / 800, group 1 / 3
# Finished unit 378 / 800, group 1 / 3
# Finished unit 379 / 800, group 1 / 3
# Finished unit 380 / 800, group 1 / 3
# Finished unit 381 / 800, group 1 / 3
# Finished unit 382 / 800, group 1 / 3
# Finished unit 383 / 800, group 1 / 3
# Finished unit 384 / 800, group 1 / 3
# Finished unit 385 / 800, group 1 / 3
# Finished unit 386 / 800, group 1 / 3
# Finished unit 387 / 800, group 1 / 3
# Finished unit 388 / 800, group 1 / 3
# Finished unit 389 / 800, group 1 / 3
# Finished unit 390 / 800, group 1 / 3
# Finished unit 391 / 800, group 1 / 3
# Finished unit 392 / 800, group 1 / 3
# Finished unit 393 / 800, group 1 / 3
# Finished unit 394 / 800, group 1 / 3
# Finished unit 395 / 800, group 1 / 3
# Finished unit 396 / 800, group 1 / 3
# Finished unit 397 / 800, group 1 / 3
# Finished unit 398 / 800, group 1 / 3
# Finished unit 399 / 800, group 1 / 3
# Finished unit 400 / 800, group 1 / 3
# Finished unit 401 / 800, group 1 / 3
# Finished unit 402 / 800, group 1 / 3
# Finished unit 403 / 800, group 1 / 3
# Finished unit 404 / 800, group 1 / 3
# Finished unit 405 / 800, group 1 / 3
# Finished unit 406 / 800, group 1 / 3
# Finished unit 407 / 800, group 1 / 3
# Finished unit 408 / 800, group 1 / 3
# Finished unit 409 / 800, group 1 / 3
# Finished unit 410 / 800, group 1 / 3
# Finished unit 411 / 800, group 1 / 3
# Finished unit 412 / 800, group 1 / 3
# Finished unit 413 / 800, group 1 / 3
# Finished unit 414 / 800, group 1 / 3
# Finished unit 415 / 800, group 1 / 3
# Finished unit 416 / 800, group 1 / 3
# Finished unit 417 / 800, group 1 / 3
# Finished unit 418 / 800, group 1 / 3
# Finished unit 419 / 800, group 1 / 3
# Finished unit 420 / 800, group 1 / 3
# Finished unit 421 / 800, group 1 / 3
# Finished unit 422 / 800, group 1 / 3
# Finished unit 423 / 800, group 1 / 3
# Finished unit 424 / 800, group 1 / 3
# Finished unit 425 / 800, group 1 / 3
# Finished unit 426 / 800, group 1 / 3
# Finished unit 427 / 800, group 1 / 3
# Finished unit 428 / 800, group 1 / 3
# Finished unit 429 / 800, group 1 / 3
# Finished unit 430 / 800, group 1 / 3
# Finished unit 431 / 800, group 1 / 3
# Finished unit 432 / 800, group 1 / 3
# Finished unit 433 / 800, group 1 / 3
# Finished unit 434 / 800, group 1 / 3
# Finished unit 435 / 800, group 1 / 3
# Finished unit 436 / 800, group 1 / 3
# Finished unit 437 / 800, group 1 / 3
# Finished unit 438 / 800, group 1 / 3
# Finished unit 439 / 800, group 1 / 3
# Finished unit 440 / 800, group 1 / 3
# Finished unit 441 / 800, group 1 / 3
# Finished unit 442 / 800, group 1 / 3
# Finished unit 443 / 800, group 1 / 3
# Finished unit 444 / 800, group 1 / 3
# Finished unit 445 / 800, group 1 / 3
# Finished unit 446 / 800, group 1 / 3
# Finished unit 447 / 800, group 1 / 3
# Finished unit 448 / 800, group 1 / 3
# Finished unit 449 / 800, group 1 / 3
# Finished unit 450 / 800, group 1 / 3
# Finished unit 451 / 800, group 1 / 3
# Finished unit 452 / 800, group 1 / 3
# Finished unit 453 / 800, group 1 / 3
# Finished unit 454 / 800, group 1 / 3
# Finished unit 455 / 800, group 1 / 3
# Finished unit 456 / 800, group 1 / 3
# Finished unit 457 / 800, group 1 / 3
# Finished unit 458 / 800, group 1 / 3
# Finished unit 459 / 800, group 1 / 3
# Finished unit 460 / 800, group 1 / 3
# Finished unit 461 / 800, group 1 / 3
# Finished unit 462 / 800, group 1 / 3
# Finished unit 463 / 800, group 1 / 3
# Finished unit 464 / 800, group 1 / 3
# Finished unit 465 / 800, group 1 / 3
# Finished unit 466 / 800, group 1 / 3
# Finished unit 467 / 800, group 1 / 3
# Finished unit 468 / 800, group 1 / 3
# Finished unit 469 / 800, group 1 / 3
# Finished unit 470 / 800, group 1 / 3
# Finished unit 471 / 800, group 1 / 3
# Finished unit 472 / 800, group 1 / 3
# Finished unit 473 / 800, group 1 / 3
# Finished unit 474 / 800, group 1 / 3
# Finished unit 475 / 800, group 1 / 3
# Finished unit 476 / 800, group 1 / 3
# Finished unit 477 / 800, group 1 / 3
# Finished unit 478 / 800, group 1 / 3
# Finished unit 479 / 800, group 1 / 3
# Finished unit 480 / 800, group 1 / 3
# Finished unit 481 / 800, group 1 / 3
# Finished unit 482 / 800, group 1 / 3
# Finished unit 483 / 800, group 1 / 3
# Finished unit 484 / 800, group 1 / 3
# Finished unit 485 / 800, group 1 / 3
# Finished unit 486 / 800, group 1 / 3
# Finished unit 487 / 800, group 1 / 3
# Finished unit 488 / 800, group 1 / 3
# Finished unit 489 / 800, group 1 / 3
# Finished unit 490 / 800, group 1 / 3
# Finished unit 491 / 800, group 1 / 3
# Finished unit 492 / 800, group 1 / 3
# Finished unit 493 / 800, group 1 / 3
# Finished unit 494 / 800, group 1 / 3
# Finished unit 495 / 800, group 1 / 3
# Finished unit 496 / 800, group 1 / 3
# Finished unit 497 / 800, group 1 / 3
# Finished unit 498 / 800, group 1 / 3
# Finished unit 499 / 800, group 1 / 3
# Finished unit 500 / 800, group 1 / 3
# Finished unit 501 / 800, group 1 / 3
# Finished unit 502 / 800, group 1 / 3
# Finished unit 503 / 800, group 1 / 3
# Finished unit 504 / 800, group 1 / 3
# Finished unit 505 / 800, group 1 / 3
# Finished unit 506 / 800, group 1 / 3
# Finished unit 507 / 800, group 1 / 3
# Finished unit 508 / 800, group 1 / 3
# Finished unit 509 / 800, group 1 / 3
# Finished unit 510 / 800, group 1 / 3
# Finished unit 511 / 800, group 1 / 3
# Finished unit 512 / 800, group 1 / 3
# Finished unit 513 / 800, group 1 / 3
# Finished unit 514 / 800, group 1 / 3
# Finished unit 515 / 800, group 1 / 3
# Finished unit 516 / 800, group 1 / 3
# Finished unit 517 / 800, group 1 / 3
# Finished unit 518 / 800, group 1 / 3
# Finished unit 519 / 800, group 1 / 3
# Finished unit 520 / 800, group 1 / 3
# Finished unit 521 / 800, group 1 / 3
# Finished unit 522 / 800, group 1 / 3
# Finished unit 523 / 800, group 1 / 3
# Finished unit 524 / 800, group 1 / 3
# Finished unit 525 / 800, group 1 / 3
# Finished unit 526 / 800, group 1 / 3
# Finished unit 527 / 800, group 1 / 3
# Finished unit 528 / 800, group 1 / 3
# Finished unit 529 / 800, group 1 / 3
# Finished unit 530 / 800, group 1 / 3
# Finished unit 531 / 800, group 1 / 3
# Finished unit 532 / 800, group 1 / 3
# Finished unit 533 / 800, group 1 / 3
# Finished unit 534 / 800, group 1 / 3
# Finished unit 535 / 800, group 1 / 3
# Finished unit 536 / 800, group 1 / 3
# Finished unit 537 / 800, group 1 / 3
# Finished unit 538 / 800, group 1 / 3
# Finished unit 539 / 800, group 1 / 3
# Finished unit 540 / 800, group 1 / 3
# Finished unit 541 / 800, group 1 / 3
# Finished unit 542 / 800, group 1 / 3
# Finished unit 543 / 800, group 1 / 3
# Finished unit 544 / 800, group 1 / 3
# Finished unit 545 / 800, group 1 / 3
# Finished unit 546 / 800, group 1 / 3
# Finished unit 547 / 800, group 1 / 3
# Finished unit 548 / 800, group 1 / 3
# Finished unit 549 / 800, group 1 / 3
# Finished unit 550 / 800, group 1 / 3
# Finished unit 551 / 800, group 1 / 3
# Finished unit 552 / 800, group 1 / 3
# Finished unit 553 / 800, group 1 / 3
# Finished unit 554 / 800, group 1 / 3
# Finished unit 555 / 800, group 1 / 3
# Finished unit 556 / 800, group 1 / 3
# Finished unit 557 / 800, group 1 / 3
# Finished unit 558 / 800, group 1 / 3
# Finished unit 559 / 800, group 1 / 3
# Finished unit 560 / 800, group 1 / 3
# Finished unit 561 / 800, group 1 / 3
# Finished unit 562 / 800, group 1 / 3
# Finished unit 563 / 800, group 1 / 3
# Finished unit 564 / 800, group 1 / 3
# Finished unit 565 / 800, group 1 / 3
# Finished unit 566 / 800, group 1 / 3
# Finished unit 567 / 800, group 1 / 3
# Finished unit 568 / 800, group 1 / 3
# Finished unit 569 / 800, group 1 / 3
# Finished unit 570 / 800, group 1 / 3
# Finished unit 571 / 800, group 1 / 3
# Finished unit 572 / 800, group 1 / 3
# Finished unit 573 / 800, group 1 / 3
# Finished unit 574 / 800, group 1 / 3
# Finished unit 575 / 800, group 1 / 3
# Finished unit 576 / 800, group 1 / 3
# Finished unit 577 / 800, group 1 / 3
# Finished unit 578 / 800, group 1 / 3
# Finished unit 579 / 800, group 1 / 3
# Finished unit 580 / 800, group 1 / 3
# Finished unit 581 / 800, group 1 / 3
# Finished unit 582 / 800, group 1 / 3
# Finished unit 583 / 800, group 1 / 3
# Finished unit 584 / 800, group 1 / 3
# Finished unit 585 / 800, group 1 / 3
# Finished unit 586 / 800, group 1 / 3
# Finished unit 587 / 800, group 1 / 3
# Finished unit 588 / 800, group 1 / 3
# Finished unit 589 / 800, group 1 / 3
# Finished unit 590 / 800, group 1 / 3
# Finished unit 591 / 800, group 1 / 3
# Finished unit 592 / 800, group 1 / 3
# Finished unit 593 / 800, group 1 / 3
# Finished unit 594 / 800, group 1 / 3
# Finished unit 595 / 800, group 1 / 3
# Finished unit 596 / 800, group 1 / 3
# Finished unit 597 / 800, group 1 / 3
# Finished unit 598 / 800, group 1 / 3
# Finished unit 599 / 800, group 1 / 3
# Finished unit 600 / 800, group 1 / 3
# Finished unit 601 / 800, group 1 / 3
# Finished unit 602 / 800, group 1 / 3
# Finished unit 603 / 800, group 1 / 3
# Finished unit 604 / 800, group 1 / 3
# Finished unit 605 / 800, group 1 / 3
# Finished unit 606 / 800, group 1 / 3
# Finished unit 607 / 800, group 1 / 3
# Finished unit 608 / 800, group 1 / 3
# Finished unit 609 / 800, group 1 / 3
# Finished unit 610 / 800, group 1 / 3
# Finished unit 611 / 800, group 1 / 3
# Finished unit 612 / 800, group 1 / 3
# Finished unit 613 / 800, group 1 / 3
# Finished unit 614 / 800, group 1 / 3
# Finished unit 615 / 800, group 1 / 3
# Finished unit 616 / 800, group 1 / 3
# Finished unit 617 / 800, group 1 / 3
# Finished unit 618 / 800, group 1 / 3
# Finished unit 619 / 800, group 1 / 3
# Finished unit 620 / 800, group 1 / 3
# Finished unit 621 / 800, group 1 / 3
# Finished unit 622 / 800, group 1 / 3
# Finished unit 623 / 800, group 1 / 3
# Finished unit 624 / 800, group 1 / 3
# Finished unit 625 / 800, group 1 / 3
# Finished unit 626 / 800, group 1 / 3
# Finished unit 627 / 800, group 1 / 3
# Finished unit 628 / 800, group 1 / 3
# Finished unit 629 / 800, group 1 / 3
# Finished unit 630 / 800, group 1 / 3
# Finished unit 631 / 800, group 1 / 3
# Finished unit 632 / 800, group 1 / 3
# Finished unit 633 / 800, group 1 / 3
# Finished unit 634 / 800, group 1 / 3
# Finished unit 635 / 800, group 1 / 3
# Finished unit 636 / 800, group 1 / 3
# Finished unit 637 / 800, group 1 / 3
# Finished unit 638 / 800, group 1 / 3
# Finished unit 639 / 800, group 1 / 3
# Finished unit 640 / 800, group 1 / 3
# Finished unit 641 / 800, group 1 / 3
# Finished unit 642 / 800, group 1 / 3
# Finished unit 643 / 800, group 1 / 3
# Finished unit 644 / 800, group 1 / 3
# Finished unit 645 / 800, group 1 / 3
# Finished unit 646 / 800, group 1 / 3
# Finished unit 647 / 800, group 1 / 3
# Finished unit 648 / 800, group 1 / 3
# Finished unit 649 / 800, group 1 / 3
# Finished unit 650 / 800, group 1 / 3
# Finished unit 651 / 800, group 1 / 3
# Finished unit 652 / 800, group 1 / 3
# Finished unit 653 / 800, group 1 / 3
# Finished unit 654 / 800, group 1 / 3
# Finished unit 655 / 800, group 1 / 3
# Finished unit 656 / 800, group 1 / 3
# Finished unit 657 / 800, group 1 / 3
# Finished unit 658 / 800, group 1 / 3
# Finished unit 659 / 800, group 1 / 3
# Finished unit 660 / 800, group 1 / 3
# Finished unit 661 / 800, group 1 / 3
# Finished unit 662 / 800, group 1 / 3
# Finished unit 663 / 800, group 1 / 3
# Finished unit 664 / 800, group 1 / 3
# Finished unit 665 / 800, group 1 / 3
# Finished unit 666 / 800, group 1 / 3
# Finished unit 667 / 800, group 1 / 3
# Finished unit 668 / 800, group 1 / 3
# Finished unit 669 / 800, group 1 / 3
# Finished unit 670 / 800, group 1 / 3
# Finished unit 671 / 800, group 1 / 3
# Finished unit 672 / 800, group 1 / 3
# Finished unit 673 / 800, group 1 / 3
# Finished unit 674 / 800, group 1 / 3
# Finished unit 675 / 800, group 1 / 3
# Finished unit 676 / 800, group 1 / 3
# Finished unit 677 / 800, group 1 / 3
# Finished unit 678 / 800, group 1 / 3
# Finished unit 679 / 800, group 1 / 3
# Finished unit 680 / 800, group 1 / 3
# Finished unit 681 / 800, group 1 / 3
# Finished unit 682 / 800, group 1 / 3
# Finished unit 683 / 800, group 1 / 3
# Finished unit 684 / 800, group 1 / 3
# Finished unit 685 / 800, group 1 / 3
# Finished unit 686 / 800, group 1 / 3
# Finished unit 687 / 800, group 1 / 3
# Finished unit 688 / 800, group 1 / 3
# Finished unit 689 / 800, group 1 / 3
# Finished unit 690 / 800, group 1 / 3
# Finished unit 691 / 800, group 1 / 3
# Finished unit 692 / 800, group 1 / 3
# Finished unit 693 / 800, group 1 / 3
# Finished unit 694 / 800, group 1 / 3
# Finished unit 695 / 800, group 1 / 3
# Finished unit 696 / 800, group 1 / 3
# Finished unit 697 / 800, group 1 / 3
# Finished unit 698 / 800, group 1 / 3
# Finished unit 699 / 800, group 1 / 3
# Finished unit 700 / 800, group 1 / 3
# Finished unit 701 / 800, group 1 / 3
# Finished unit 702 / 800, group 1 / 3
# Finished unit 703 / 800, group 1 / 3
# Finished unit 704 / 800, group 1 / 3
# Finished unit 705 / 800, group 1 / 3
# Finished unit 706 / 800, group 1 / 3
# Finished unit 707 / 800, group 1 / 3
# Finished unit 708 / 800, group 1 / 3
# Finished unit 709 / 800, group 1 / 3
# Finished unit 710 / 800, group 1 / 3
# Finished unit 711 / 800, group 1 / 3
# Finished unit 712 / 800, group 1 / 3
# Finished unit 713 / 800, group 1 / 3
# Finished unit 714 / 800, group 1 / 3
# Finished unit 715 / 800, group 1 / 3
# Finished unit 716 / 800, group 1 / 3
# Finished unit 717 / 800, group 1 / 3
# Finished unit 718 / 800, group 1 / 3
# Finished unit 719 / 800, group 1 / 3
# Finished unit 720 / 800, group 1 / 3
# Finished unit 721 / 800, group 1 / 3
# Finished unit 722 / 800, group 1 / 3
# Finished unit 723 / 800, group 1 / 3
# Finished unit 724 / 800, group 1 / 3
# Finished unit 725 / 800, group 1 / 3
# Finished unit 726 / 800, group 1 / 3
# Finished unit 727 / 800, group 1 / 3
# Finished unit 728 / 800, group 1 / 3
# Finished unit 729 / 800, group 1 / 3
# Finished unit 730 / 800, group 1 / 3
# Finished unit 731 / 800, group 1 / 3
# Finished unit 732 / 800, group 1 / 3
# Finished unit 733 / 800, group 1 / 3
# Finished unit 734 / 800, group 1 / 3
# Finished unit 735 / 800, group 1 / 3
# Finished unit 736 / 800, group 1 / 3
# Finished unit 737 / 800, group 1 / 3
# Finished unit 738 / 800, group 1 / 3
# Finished unit 739 / 800, group 1 / 3
# Finished unit 740 / 800, group 1 / 3
# Finished unit 741 / 800, group 1 / 3
# Finished unit 742 / 800, group 1 / 3
# Finished unit 743 / 800, group 1 / 3
# Finished unit 744 / 800, group 1 / 3
# Finished unit 745 / 800, group 1 / 3
# Finished unit 746 / 800, group 1 / 3
# Finished unit 747 / 800, group 1 / 3
# Finished unit 748 / 800, group 1 / 3
# Finished unit 749 / 800, group 1 / 3
# Finished unit 750 / 800, group 1 / 3
# Finished unit 751 / 800, group 1 / 3
# Finished unit 752 / 800, group 1 / 3
# Finished unit 753 / 800, group 1 / 3
# Finished unit 754 / 800, group 1 / 3
# Finished unit 755 / 800, group 1 / 3
# Finished unit 756 / 800, group 1 / 3
# Finished unit 757 / 800, group 1 / 3
# Finished unit 758 / 800, group 1 / 3
# Finished unit 759 / 800, group 1 / 3
# Finished unit 760 / 800, group 1 / 3
# Finished unit 761 / 800, group 1 / 3
# Finished unit 762 / 800, group 1 / 3
# Finished unit 763 / 800, group 1 / 3
# Finished unit 764 / 800, group 1 / 3
# Finished unit 765 / 800, group 1 / 3
# Finished unit 766 / 800, group 1 / 3
# Finished unit 767 / 800, group 1 / 3
# Finished unit 768 / 800, group 1 / 3
# Finished unit 769 / 800, group 1 / 3
# Finished unit 770 / 800, group 1 / 3
# Finished unit 771 / 800, group 1 / 3
# Finished unit 772 / 800, group 1 / 3
# Finished unit 773 / 800, group 1 / 3
# Finished unit 774 / 800, group 1 / 3
# Finished unit 775 / 800, group 1 / 3
# Finished unit 776 / 800, group 1 / 3
# Finished unit 777 / 800, group 1 / 3
# Finished unit 778 / 800, group 1 / 3
# Finished unit 779 / 800, group 1 / 3
# Finished unit 780 / 800, group 1 / 3
# Finished unit 781 / 800, group 1 / 3
# Finished unit 782 / 800, group 1 / 3
# Finished unit 783 / 800, group 1 / 3
# Finished unit 784 / 800, group 1 / 3
# Finished unit 785 / 800, group 1 / 3
# Finished unit 786 / 800, group 1 / 3
# Finished unit 787 / 800, group 1 / 3
# Finished unit 788 / 800, group 1 / 3
# Finished unit 789 / 800, group 1 / 3
# Finished unit 790 / 800, group 1 / 3
# Finished unit 791 / 800, group 1 / 3
# Finished unit 792 / 800, group 1 / 3
# Finished unit 793 / 800, group 1 / 3
# Finished unit 794 / 800, group 1 / 3
# Finished unit 795 / 800, group 1 / 3
# Finished unit 796 / 800, group 1 / 3
# Finished unit 797 / 800, group 1 / 3
# Finished unit 798 / 800, group 1 / 3
# Finished unit 799 / 800, group 1 / 3
# Finished unit 800 / 800, group 1 / 3
# /home/seb/.local/lib/python3.7/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Finished unit 1 / 97, group 2 / 3
# Finished unit 2 / 97, group 2 / 3
# Finished unit 3 / 97, group 2 / 3
# Finished unit 4 / 97, group 2 / 3
# Finished unit 5 / 97, group 2 / 3
# Finished unit 6 / 97, group 2 / 3
# Finished unit 7 / 97, group 2 / 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31858/1199002031.py in <module>
#      21 )
#      22
# ---> 23 vphys_nofb.get_plaid_pattern_index()
#
# ~/rnn_hierarchical/virtual_physiology_20x40/VirtualNetworkPhysiology.py in get_plaid_pattern_index(self, grating_amplitude)
#     553
#     554                             # Feed into model
# --> 555                             _, hidden_state = self.model(plaid)
#     556
#     557                             # Get mean response for current unit
#
# ~/anaconda3/envs/allensdk/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/rnn_hierarchical/models/network_hierarchical_recurrent.py in forward(self, inputs)
#     168
#     169         # Forward pass
# --> 170         rnn_outputs, _ = self.rnn(inputs)
#     171         fc_outputs = self.fc(rnn_outputs)
#     172
#
# ~/anaconda3/envs/allensdk/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/allensdk/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     475                 result = _VF.rnn_relu(input, hx, self._flat_weights, self.bias, self.num_layers,
#     476                                       self.dropout, self.training, self.bidirectional,
# --> 477                                       self.batch_first)
#     478         else:
#     479             if self.mode == 'RNN_TANH':
#
# KeyboardInterrupt:

# %%
full = not_nan([u['plaid_pattern_index'] for u in vphys.data[0]])
nofb = not_nan([u['plaid_pattern_index'] for u in vphys_nofb.data[0]])

mn = np.array([
    np.mean(full),
    np.mean(nofb)
])
er = np.array([
    np.std(full)/(len(full)**2),
    np.mean(nofb)/(len(nofb)**2),
])

x = np.array([0, 1])
labels = ['Full model', 'No feedback']
c = [COLORS[0], COLORS[0]]

fig = plt.figure()
plt.bar(x, mn, yerr=er)
plt.xticks(x, labels)
format_plot(fontsize=20)
fig.set_size_inches((4, 4))
plt.show()

fig = plt.figure()
vp = plt.violinplot([full, nofb], x, showmedians=False, showextrema=False)
plt.xticks(x, labels)
for i, pc in enumerate(vp["bodies"], 0):
    pc.set_facecolor(c[i])
    pc.set_edgecolor('black')
    pc.set_alpha(0.8)
plt.hlines(mn, x-0.5, x+0.5, linewidth=2, color='black', zorder=3, alpha=0.8)
plt.ylabel('Plaid pattern index')
format_plot(fontsize=20)
fig.set_size_inches(5, 4)
plt.savefig(f'./figures/plaid_response/nofb_mean_multicompangle.pdf', bbox_inches='tight')
plt.show()  

pg.ttest(full, nofb, paired=True)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /home/seb/anaconda3/envs/allensdk/lib/python3.7/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
#                T          dof alternative         p-val        CI95%  \
# T-test  5.326449  1519.148009   two-sided  1.151971e-07  [0.33, 0.7]
#
#          cohen-d       BF10     power
# T-test  0.266443  6.359e+04  0.999616

# %%
def centre_shift (arr, axis, shift=False):
    arr = np.array(arr)
    
    if not shift:
        max_idx = np.argmax(arr, axis=axis)
        max_idx = stats.mode(max_idx).mode[0]
        shift = int(np.ceil(arr.shape[axis]/2) - max_idx)
    
    return np.roll(arr, shift, axis=axis), shift

group_idx = 0

plaid_ori_list = np.arange(0, 360, 20)
centred_plaid_ori_list = np.arange(-180, 180, 20)
delta_ori_list = [0, 30, 60, 90, 120, 150]

units = [*vphys.data[0], *vphys.data[2]]

c = 0

for vphys_to_use, model_to_use in zip([vphys, vphys_nofb], [model, model_nofb]):

    for unit_i, unit in enumerate(units):   
        if not unit['hidden_unit_index'] in [2079]: # 2079
            continue

        print('Starting unit ', unit['hidden_unit_index'])

        response_curves_list = []

        for delta_ori in delta_ori_list:
            response_curve = []
            for plaid_ori in plaid_ori_list:
                ori_a = plaid_ori - delta_ori//2
                ori_b = plaid_ori + delta_ori//2

                grating_a = vphys_to_use.get_grating_stimuli(unit['preferred_sf'], ori_a, unit['preferred_tf'], 1, 50)
                grating_b = vphys_to_use.get_grating_stimuli(unit['preferred_sf'], ori_b, unit['preferred_tf'], 1, 50)
                plaid = grating_a+grating_b
                #plaid = (plaid-torch.mean(plaid))/torch.std(plaid)

                with torch.no_grad():
                    _, h = model_to_use(plaid)

                mean_res = np.mean(h[0, WARMUP:, unit['hidden_unit_index']].detach().numpy(), axis=0)
                response_curve.append( mean_res )

            if delta_ori == 0:
                shifted_curve, shift = centre_shift(response_curve, axis=0, shift=False)
            else:
                shifted_curve, _ = centre_shift(response_curve, axis=0, shift=shift)

            response_curves_list.append(shifted_curve)

        fig = plt.figure()

        for curve, delta in zip(response_curves_list, delta_ori_list):
            plt.plot(centred_plaid_ori_list, curve, label=delta)
        plt.ylabel('Unit response')
        plt.xlabel('Orientation (°)')
        format_plot(fontsize=20)
        fig.set_size_inches(4, 4)
        plt.gca().get_legend().set_visible(False)
        plt.show()

        c += 1

# %% [markdown]
# # Pattern index distributions

# %%
g1_dist = not_nan([u['plaid_pattern_index'] for u in vphys.data[0]])
g2_dist = not_nan([u['plaid_pattern_index'] for u in vphys.data[1]])
g3_dist = not_nan([u['plaid_pattern_index'] for u in vphys.data[2]])


labels = ['$\mathregular{G_1}$', 'V1', '$\mathregular{G_2}$', 'V2', '$\mathregular{G_3}$', 'MT']
all_dists = [g1_dist, PI_dist_V1, g2_dist, PI_dist_V2, g3_dist, PI_dist_MT]
c = [COLORS[0], 'grey', [168/255,199/255,218/255], 'grey', [213/255,227/255,237/255], 'grey']

means = [np.mean(g1_dist), np.mean(PI_dist_V1),  np.mean(g2_dist), np.mean(PI_dist_V2), np.mean(g3_dist), np.mean(PI_dist_MT)]

x = np.array([0, 1, 2.5, 3.5, 5, 6])

fig = plt.figure()
vp = plt.violinplot(all_dists, x, showmedians=False, showextrema=False)
plt.xticks(x, labels)
for i, pc in enumerate(vp["bodies"], 0):
    pc.set_facecolor(c[i])
    pc.set_edgecolor('black')
    pc.set_alpha(0.8)
plt.hlines(means, x-0.5, x+0.5, linewidth=2, color='black', zorder=3, alpha=0.8)
plt.ylabel('Plaid pattern index')
format_plot(fontsize=20)
fig.set_size_inches(8, 4)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
anova_df = {
    'group': [],
    'plaid_index': []
}
for g_idx, g in enumerate([g1_dist, g2_dist, g3_dist]):
    anova_df['group'] += list(np.ones(len(g))*g_idx)
    anova_df['plaid_index'] += list(g)
display(pg.anova(data=pd.DataFrame(anova_df), dv='plaid_index', between='group'))

anova_df = {
    'group': [],
    'plaid_index': []
}
for g_idx, g in enumerate([PI_dist_V1, PI_dist_V2, PI_dist_MT]):
    anova_df['group'] += list(np.ones(len(g))*g_idx)
    anova_df['plaid_index'] += list(g)
display(pg.anova(data=pd.DataFrame(anova_df), dv='plaid_index', between='group'))

p_vals = []
label_combos = []
for combo in combinations(zip(labels, all_dists), 2): 
    a, b = combo
    a_label, a_dist = a
    b_label, b_dist = b
    
    ttest = stats.ttest_ind(a_dist, b_dist)
    print(a_label, 'vs', b_label, '\t\t', ttest)
    
    p_vals.append(ttest[1])
    label_combos.append(f'{a_label} vs {b_label}')

p_vals_corr = pg.multicomp(p_vals, method='holm')
    
print('\n')
for pair, p_t, p_v in zip(label_combos, p_vals_corr[0], p_vals_corr[1]):
    print(pair, '\t', p_t, '\t', p_v)

print('\n')
print(np.mean(g1_dist), np.mean(g2_dist), np.mean(g3_dist), np.mean(PI_dist_V1), np.mean(PI_dist_V2), np.mean(PI_dist_MT))
# Out:
#   Source  ddof1  ddof2          F         p-unc       np2
# 0  group      2    931  61.550653  7.840469e-26  0.116783
#   Source  ddof1  ddof2          F         p-unc       np2
# 0  group      2    276  24.918806  1.125345e-10  0.152952
# G1 vs V1 		 Ttest_indResult(statistic=0.2467885950392914, pvalue=0.8051324972773093)
# G1 vs G2 		 Ttest_indResult(statistic=-8.8983514174656, pvalue=3.1031139167006273e-18)
# G1 vs V2 		 Ttest_indResult(statistic=-5.540090320585352, pvalue=4.024525253161374e-08)
# G1 vs G3 		 Ttest_indResult(statistic=-7.0738835787083, pvalue=3.1862402490689675e-12)
# G1 vs MT 		 Ttest_indResult(statistic=-16.759276742064316, pvalue=1.2850808229259555e-55)
# V1 vs G2 		 Ttest_indResult(statistic=-5.298106550192599, pvalue=4.766429428767097e-07)
# V1 vs V2 		 Ttest_indResult(statistic=-3.134102611240112, pvalue=0.002293259746404766)
# V1 vs G3 		 Ttest_indResult(statistic=-5.270928853814465, pvalue=1.2610359360578888e-06)
# V1 vs MT 		 Ttest_indResult(statistic=-6.676165454003493, pvalue=2.0043054269212465e-10)
# G2 vs V2 		 Ttest_indResult(statistic=1.0813334904578025, pvalue=0.2812502252257401)
# G2 vs G3 		 Ttest_indResult(statistic=-1.2255087111880094, pvalue=0.222549335842785)
# G2 vs MT 		 Ttest_indResult(statistic=-3.4539092258690003, pvalue=0.000639336066802742)
# V2 vs G3 		 Ttest_indResult(statistic=-1.704498223498875, pvalue=0.09152255423607074)
# V2 vs MT 		 Ttest_indResult(statistic=-3.625713644201397, pvalue=0.000352151932501279)
# G3 vs MT 		 Ttest_indResult(statistic=-1.4337435416593685, pvalue=0.15307165702397174)
#
#
# G1 vs V1 	 False 	 0.8051324972773093
# G1 vs G2 	 True 	 4.3443594833808784e-17
# G1 vs V2 	 True 	 4.426977778477512e-07
# G1 vs G3 	 True 	 4.1421123237896575e-11
# G1 vs MT 	 True 	 1.9276212343889334e-54
# V1 vs G2 	 True 	 4.766429428767097e-06
# V1 vs V2 	 True 	 0.013759558478428595
# V1 vs G3 	 True 	 1.1349323424520998e-05
# V1 vs MT 	 True 	 2.4051665123054957e-09
# G2 vs V2 	 False 	 0.667648007528355
# G2 vs G3 	 False 	 0.667648007528355
# G2 vs MT 	 True 	 0.0044753524676191935
# V2 vs G3 	 False 	 0.4576127711803537
# V2 vs MT 	 True 	 0.002817215460010232
# G3 vs MT 	 False 	 0.612286628095887
#
#
# -3.5986443965849038 -1.5647384189732556 -1.1387422073670666 -3.6870872003347652 -1.9661238371275744 -0.4898404614375463

# %% [markdown]
# # Model comparison

# %%
def not_nan (arr):
    return [a for a in arr if not np.isnan(a)]

TP_model, hyperparameters, loss_history = NetworkHierarchicalRecurrent.load(
    model_path='',
    device='cpu',
    plot_loss_history=False
)
TP_vphys = VirtualPhysiology.load(
    data_path='',
    model=TP_model,
    hyperparameters=hyperparameters,
    hidden_units=[800, 800, 800],
    frame_shape=(20, 40),
    device='cpu'
)

TP_ff_model = NetworkFeedforwardStacked([])
TP_ff_vphys = VirtualPhysiology.load(
    data_path='',
    model=TP_ff_model,
    hyperparameters=TP_ff_model.stacks[0].hyperparameters,
    hidden_units=[800, 800, 800],
    frame_shape=(20, 40),
    device='cpu'
)

AE_model, hyperparameters, loss_history = NetworkHierarchicalRecurrent.load(
    model_path='',
    device='cpu',
    plot_loss_history=False
)
AE_vphys = VirtualPhysiology.load(
    data_path='',
    model=AE_model,
    hyperparameters=hyperparameters,
    hidden_units=[800, 800, 800],
    frame_shape=(20, 40),
    device='cpu'
)


all_model_dists = []

ks_dist = []

for vphys_i, (vphys, color) in enumerate(zip([TP_vphys, TP_ff_vphys, AE_vphys], COLORS)):
    g1_dist = not_nan([u['plaid_pattern_index'] for u in vphys.data[0]])
    g2_dist = not_nan([u['plaid_pattern_index'] for u in vphys.data[1]])
    g3_dist = not_nan([u['plaid_pattern_index'] for u in vphys.data[2]])

    all_model_dists.append([g1_dist, g2_dist, g3_dist])
    
    labels = ['$\mathregular{G_{1}}$', 'V1', '$\mathregular{G_{2}}$', 'V2', '$\mathregular{G_{3}}$', 'MT']
    all_dists = [g1_dist, PI_dist_V1, g2_dist, PI_dist_V2, g3_dist, PI_dist_MT]
    c = [color, 'grey', color, 'grey', color, 'grey']

    means = [np.mean(g1_dist), np.mean(PI_dist_V1),  np.mean(g2_dist), np.mean(PI_dist_V2), np.mean(g3_dist), np.mean(PI_dist_MT)]

    x = np.array([0, 1, 3, 4, 6, 7])

    fig = plt.figure()
    vp = plt.violinplot(all_dists, x, showmedians=False, showextrema=False)
    plt.xticks(x, labels)
    for i, pc in enumerate(vp["bodies"], 0):
        pc.set_facecolor(c[i])
        pc.set_edgecolor('black')
        pc.set_alpha(0.8)
    plt.hlines(means, x-0.5, x+0.5, linewidth=2, color='black', zorder=3, alpha=0.8)
    if vphys_i == '':
        plt.ylabel('Plaid pattern index')
    format_plot(fontsize=20)
    fig.set_size_inches(4, 4)
    plt.ylim(-12.5, 12.5)
    plt.savefig(f'./figures/model_comparison/B_{["i", "ii", "iii"][vphys_i]}_multicompangle.pdf', bbox_inches='tight')
    plt.show()  
    
    ks_dist.append([
        stats.ks_2samp(g1_dist, PI_dist_V1)[0],
        stats.ks_2samp(g2_dist, PI_dist_V2)[0],
        stats.ks_2samp(g3_dist, PI_dist_MT)[0]
    ])
    
    p_vals = []
    label_combos = []
    for combo in combinations(zip(labels, all_dists), 2): 
        a, b = combo
        a_label, a_dist = a
        b_label, b_dist = b

        ttest = stats.ttest_ind(a_dist, b_dist)
        print(a_label, 'vs', b_label, '\t\t', ttest)

        p_vals.append(ttest[1])
        label_combos.append(f'{a_label} vs {b_label}')

    
x = [0, 1, 2]
fig = plt.figure()
b = plt.bar(x, [np.mean(d) for d in ks_dist], yerr=[np.std(d)/(len(d)**0.5) for d in ks_dist], facecolor='tab:gray')
for b_i, c_i in zip(b, COLORS):
    b_i.set_facecolor(c_i)
plt.xticks(x, ['$\mathregular{TP_{full}}$', '$\mathregular{TP_{FF}}$', 'AE'], rotation=0)
plt.ylabel('KS distance')
format_plot(fontsize=20)
fig.set_size_inches(3, 4)
plt.savefig(f'./figures/model_comparison/B_iv_multicompangle.pdf', bbox_inches='tight')
plt.show()
# Out:
# /media/seb/Elements/rnn_models/feedforward/L1-6.0_Feb 3-07-52/0-stack_1000-epochs_model.pt
# /media/seb/Elements/rnn_models/feedforward/L1-6.0_Feb10-00-52/1-stack_1000-epochs_model.pt
# /media/seb/Elements/rnn_models/feedforward/L1-6.0_Feb15-00-44/2-stack_1000-epochs_model.pt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# $\mathregular{G_{1}}$ vs V1 		 Ttest_indResult(statistic=0.2467885950392914, pvalue=0.8051324972773093)
# $\mathregular{G_{1}}$ vs $\mathregular{G_{2}}$ 		 Ttest_indResult(statistic=-8.8983514174656, pvalue=3.1031139167006273e-18)
# $\mathregular{G_{1}}$ vs V2 		 Ttest_indResult(statistic=-5.540090320585352, pvalue=4.024525253161374e-08)
# $\mathregular{G_{1}}$ vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-7.0738835787083, pvalue=3.1862402490689675e-12)
# $\mathregular{G_{1}}$ vs MT 		 Ttest_indResult(statistic=-16.759276742064316, pvalue=1.2850808229259555e-55)
# V1 vs $\mathregular{G_{2}}$ 		 Ttest_indResult(statistic=-5.298106550192599, pvalue=4.766429428767097e-07)
# V1 vs V2 		 Ttest_indResult(statistic=-3.134102611240112, pvalue=0.002293259746404766)
# V1 vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-5.270928853814465, pvalue=1.2610359360578888e-06)
# V1 vs MT 		 Ttest_indResult(statistic=-6.676165454003493, pvalue=2.0043054269212465e-10)
# $\mathregular{G_{2}}$ vs V2 		 Ttest_indResult(statistic=1.0813334904578025, pvalue=0.2812502252257401)
# $\mathregular{G_{2}}$ vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-1.2255087111880094, pvalue=0.222549335842785)
# $\mathregular{G_{2}}$ vs MT 		 Ttest_indResult(statistic=-3.4539092258690003, pvalue=0.000639336066802742)
# V2 vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-1.704498223498875, pvalue=0.09152255423607074)
# V2 vs MT 		 Ttest_indResult(statistic=-3.625713644201397, pvalue=0.000352151932501279)
# $\mathregular{G_{3}}$ vs MT 		 Ttest_indResult(statistic=-1.4337435416593685, pvalue=0.15307165702397174)
# No handles with labels found to put in legend.
# $\mathregular{G_{1}}$ vs V1 		 Ttest_indResult(statistic=-6.561296031481083, pvalue=9.345615355204834e-11)
# $\mathregular{G_{1}}$ vs $\mathregular{G_{2}}$ 		 Ttest_indResult(statistic=-1.3666926448805452, pvalue=0.17199424089543852)
# $\mathregular{G_{1}}$ vs V2 		 Ttest_indResult(statistic=-13.844973649986544, pvalue=1.731009156672543e-39)
# $\mathregular{G_{1}}$ vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-6.450094037857987, pvalue=1.6109734989166767e-10)
# $\mathregular{G_{1}}$ vs MT 		 Ttest_indResult(statistic=-29.966876925161714, pvalue=1.4266846808609171e-140)
# V1 vs $\mathregular{G_{2}}$ 		 Ttest_indResult(statistic=6.649626042136968, pvalue=1.0744918255002962e-10)
# V1 vs V2 		 Ttest_indResult(statistic=-3.134102611240112, pvalue=0.002293259746404766)
# V1 vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=5.173277228218084, pvalue=3.4673887714705926e-07)
# V1 vs MT 		 Ttest_indResult(statistic=-6.676165454003493, pvalue=2.0043054269212465e-10)
# $\mathregular{G_{2}}$ vs V2 		 Ttest_indResult(statistic=-13.903939294006674, pvalue=6.495650735354119e-36)
# $\mathregular{G_{2}}$ vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-4.607301048364629, pvalue=4.800721905670843e-06)
# $\mathregular{G_{2}}$ vs MT 		 Ttest_indResult(statistic=-26.625936838899648, pvalue=1.7104366885462103e-98)
# V2 vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=12.715489450626857, pvalue=4.646275502519439e-32)
# V2 vs MT 		 Ttest_indResult(statistic=-3.625713644201397, pvalue=0.000352151932501279)
# $\mathregular{G_{3}}$ vs MT 		 Ttest_indResult(statistic=-25.93487851549964, pvalue=8.535417141659833e-100)
# No handles with labels found to put in legend.
# $\mathregular{G_{1}}$ vs V1 		 Ttest_indResult(statistic=22.42591133322612, pvalue=9.942360200235242e-85)
# $\mathregular{G_{1}}$ vs $\mathregular{G_{2}}$ 		 Ttest_indResult(statistic=4.681084343494873, pvalue=3.4176365335896073e-06)
# $\mathregular{G_{1}}$ vs V2 		 Ttest_indResult(statistic=12.479349724771488, pvalue=1.488532799830821e-32)
# $\mathregular{G_{1}}$ vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=0.5909954351997629, pvalue=0.5547172978116905)
# $\mathregular{G_{1}}$ vs MT 		 Ttest_indResult(statistic=2.682569500180716, pvalue=0.007446424355491635)
# V1 vs $\mathregular{G_{2}}$ 		 Ttest_indResult(statistic=-6.005498515512933, pvalue=7.363219813942031e-08)
# V1 vs V2 		 Ttest_indResult(statistic=-3.134102611240112, pvalue=0.002293259746404766)
# V1 vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-4.673610958066904, pvalue=2.3457960618699626e-05)
# V1 vs MT 		 Ttest_indResult(statistic=-6.676165454003493, pvalue=2.0043054269212465e-10)
# $\mathregular{G_{2}}$ vs V2 		 Ttest_indResult(statistic=2.3277694376641893, pvalue=0.022117146969305366)
# $\mathregular{G_{2}}$ vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-1.2574966272693926, pvalue=0.2149206876520204)
# $\mathregular{G_{2}}$ vs MT 		 Ttest_indResult(statistic=-0.706283804998786, pvalue=0.48077632146253235)
# V2 vs $\mathregular{G_{3}}$ 		 Ttest_indResult(statistic=-2.1622423028319377, pvalue=0.03401906668195375)
# V2 vs MT 		 Ttest_indResult(statistic=-3.625713644201397, pvalue=0.000352151932501279)
# $\mathregular{G_{3}}$ vs MT 		 Ttest_indResult(statistic=0.2505338562728135, pvalue=0.8024410281593674)

# %% [markdown]
# # Contour plots

# %%
def centre_shift (arr, axis):
    max_idx = np.argmax(arr, axis=axis)
    max_idx = stats.mode(max_idx).mode[0]
    shift = int(np.ceil(arr.shape[axis]/2) - 1 - max_idx)
    
    return np.roll(arr, shift, axis=axis)

a = np.arange(0, 360, 25)
b = np.arange(0, 360, 25)

units = [*vphys.data[0], *vphys.data[2]]

c = 0

for unit_i, unit in enumerate(units):
    if not unit['hidden_unit_index'] in [8, 585]: # 2079
        continue 
        
    print('Starting unit ', unit['hidden_unit_index'])
    contour = np.zeros(shape=(len(a), len(b)))
    for a_idx, a_i in enumerate(a):
        print('\tProcessing orientation', a_i, 'degrees')
        for b_idx, b_i in enumerate(b):
            grating_a = vphys.get_grating_stimuli(unit['preferred_sf'], a_i, unit['preferred_tf'], 1, 50)
            grating_b = vphys.get_grating_stimuli(unit['preferred_sf'], b_i, unit['preferred_tf'], 1, 50)
            
            plaid = grating_a+grating_b
            plaid = (plaid-torch.mean(plaid))/torch.std(plaid)
            
            with torch.no_grad():
                _, h = model(plaid)


            mean_res = np.mean(h[0, WARMUP:, unit['hidden_unit_index']].detach().numpy(), axis=0)
            contour[a_idx, b_idx] = mean_res

    contour = centre_shift(contour, 0)
    contour = centre_shift(contour, 1)
    
    fig = plt.figure()
    plt.contourf(np.arange(-180, 180, 25), np.arange(-180, 180, 25), contour)
    plt.xlabel('B orientation (°)')
    plt.ylabel('A orientation (°)')
    format_plot(fontsize=20)
    fig.set_size_inches(3, 3)
    plt.savefig(f'./figures/plaid_response/c_{"".join(np.repeat("i", c+1))}.pdf', bbox_inches='tight')
    plt.show()
    
    c += 1

# %%
def centre_shift (arr, axis, shift=False):
    arr = np.array(arr)
    
    if not shift:
        max_idx = np.argmax(arr, axis=axis)
        max_idx = stats.mode(max_idx).mode[0]
        shift = int(np.ceil(arr.shape[axis]/2) - max_idx)
    
    return np.roll(arr, shift, axis=axis), shift

group_idx = 0

plaid_ori_list = np.arange(0, 360, 20)
centred_plaid_ori_list = np.arange(-180, 180, 20)
delta_ori_list = [0, 30, 60, 90, 120, 150]

units = [*vphys.data[0], *vphys.data[2]]

c = 0

for unit_i, unit in enumerate(units):   
    if not unit['hidden_unit_index'] in [8, 585]: # 2079
        continue
        
    print('Starting unit ', unit['hidden_unit_index'])
    
    response_curves_list = []
    
    for delta_ori in delta_ori_list:
        response_curve = []
        for plaid_ori in plaid_ori_list:
            ori_a = plaid_ori - delta_ori//2
            ori_b = plaid_ori + delta_ori//2

            grating_a = vphys.get_grating_stimuli(unit['preferred_sf'], ori_a, unit['preferred_tf'], 1, 50)
            grating_b = vphys.get_grating_stimuli(unit['preferred_sf'], ori_b, unit['preferred_tf'], 1, 50)
            plaid = grating_a+grating_b
            
            with torch.no_grad():
                _, h = model(plaid)

            mean_res = np.mean(h[0, WARMUP:, unit['hidden_unit_index']].detach().numpy(), axis=0)
            response_curve.append( mean_res )
            
        if delta_ori == 0:
            shifted_curve, shift = centre_shift(response_curve, axis=0, shift=False)
        else:
            shifted_curve, _ = centre_shift(response_curve, axis=0, shift=shift)
        
        response_curves_list.append(shifted_curve)

    fig = plt.figure()
    
    for curve, delta in zip(response_curves_list, delta_ori_list):
        plt.plot(centred_plaid_ori_list, curve, label=delta)
    plt.ylabel('Unit response')
    plt.xlabel('Orientation (°)')
    format_plot(fontsize=20)
    fig.set_size_inches(3, 3)
    plt.gca().get_legend().set_visible(False)
    plt.savefig(f'./figures/plaid_response/d_{"".join(np.repeat("i", c+1))}.pdf', bbox_inches='tight')
    plt.show()
    
    c += 1
